# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('/kaggle/input/c/spaceship-titanic/train.csv')
df.head()

# %%
df.info()

# %%
df.isna().sum()

# %%
df.dropna(inplace=True)
df.isna().sum()

# %%
df.info()

# %%
df = df[['RoomService','Spa','FoodCourt','ShoppingMall','Age','VIP','CryoSleep','Transported']]
df.head()

# %%
sns.pairplot(df,corner=True,hue='Transported');

# %%
df['VIP'] = df['VIP'].astype('int')
df['CryoSleep'] = df['CryoSleep'].astype('int')

# %%
df = pd.get_dummies(df,drop_first=True, dtype='int')
df.head()

# %%
X = df.drop('Transported',axis=1)
y = df['Transported']

X.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, test_size=0.2)

# %%
model =LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
X_test['actual'] = y_test
X_test['predicted'] = y_pred

X_test[X_test['actual'] != X_test['predicted']]

# %%
print(classification_report(y_test, y_pred))

# %%
cross_validate(model, X,y, scoring='accuracy')['test_score']
